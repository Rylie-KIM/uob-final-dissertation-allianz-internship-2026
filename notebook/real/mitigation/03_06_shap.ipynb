# %% [markdown]
# # 03-06 · SHAP pre/post mitigation — MOVED
#
# This notebook was a stub for two tasks:
#
# 1. compare feature concentration pre-mitigation vs post-mitigation.
# 2. compare SHAP-DiD pre-mitigation vs post-mitigation.
#
# Both now live at **`notebook/real/shap_did/04_03_shap_did_mitigation_delta.ipynb`**, next to the rest of the SHAP-DiD chain (04_01/04_02/04_04) it depends on and reuses helpers from. Built 2026-09-12 — see `project_shap_did_04_03_04_built` in memory for what it does and what it still needs (mitigated-model attributions do not exist anywhere yet).
#
# This file is kept only as a pointer so an old link/reference does not dead-end. Do not add cells here — add them to 04_03 instead.
